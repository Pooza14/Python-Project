# %%
customer_name=input("Please! Enter your name:")
print("\nWelcome To The Snazzy Auto Shop!",customer_name)


model=["Hatchback:Rs 5.35Lakhs","Saloon:Rs 4.95Lakhs","Estate:Rs 6.25Lakhs"]
print("\nThese are available models of car:")
for i in model:
    print(i)
    
optional_extra=["Luxury budget:Rs 45000","Satellite navigation:Rs 5500","Parking sensors:1000","Bluetooth connect:350","Sound system:Rs 1000"]
print("\nThese are facilities provided in our car:")
for j in optional_extra:
    print(j)
    
customer_choice=input("\nPlease! enter your choosen car model(Hatchback/Saloon/Estate):")
choosen_facilities=input("Please enter your choice of facilities(Luxury budget/Satellite navigation/Parking sensors/Bluetooth connect/Sound system):")

customer_details=input("Are you have old car?(Yes or No):")

if customer_details=="Yes":
    cost_of_old_car=int(input("Enter the price of your old car:"))
    print("The price of old car:",cost_of_old_car)
    if customer_choice=="Hatchback" and choosen_facilities=="Luxury budget":   #condition for Hatchback model
            tot=(535000+45000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Satellite navigation":
            tot=(535000+5500)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Parking sensors":
            tot=(535000+10000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Bluetooth connect":
            tot=(535000+350)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Sound system":
            tot=(535000+1000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Luxury budget":     #condition for saloon model
            tot=(495000+45000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Satellite navigation":
            tot=(495000+5500)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Parking sensors":
            tot=(495000+10000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Bluetooth connect":
            tot=(495000+350)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Sound system":
            tot=(495000+1000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Luxury budget":      #condition for Estate model
            tot=(625000+45000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Satellite navigation":
            tot=(625000+5500)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Parking sensors":
            tot=(625000+10000)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and  choosen_facilities=="Bluetooth connect":
            tot=(625000+350)-cost_of_old_car
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Sound system":
            tot=(625000+1000)-cost_of_old_car
            print("Your total price is:",tot)
    
else:
    print("So, you don't have old car.")
    if customer_choice=="Hatchback" and choosen_facilities=="Luxury budget":   #condition for Hatchback model
            tot=(535000+45000)
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Satellite navigation":
            tot=(535000+5500)
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Parking sensors":
            tot=(535000+10000)
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Bluetooth connect":
            tot=(535000+350)
            print("Your total price is:",tot)
    elif customer_choice=="Hatchback" and choosen_facilities=="Sound system":
            tot=(535000+1000)
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Luxury budget":     #condition for saloon model
            tot=(495000+45000)
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Satellite navigation":
            tot=(495000+5500)
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Parking sensors":
            tot=(495000+10000)
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Bluetooth connect":
            tot=(495000+350)
            print("Your total price is:",tot)
    elif customer_choice=="Saloon" and choosen_facilities=="Sound system":
            tot=(495000+1000)
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Luxury budget":      #condition for Estate model
            tot=(625000+45000)
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Satellite navigation":
            tot=(625000+5500)
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Parking sensors":
            tot=(625000+10000)
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and  choosen_facilities=="Bluetooth connect":
            tot=(625000+350)
            print("Your total price is:",tot)
    elif customer_choice=="Estate" and choosen_facilities=="Sound system":
            tot=(625000+1000)
            print("Your total price is:",tot)
        
print("\nThe total amount that you have to pay is:",tot)
print("\nFor getting excited offers, select your suitable payment methods.\n")   #task3
print('''\nIf you choose fullpayment methods and you are repeated customers then you have two options:
1)1% Cashback of your total payment.
2)Any one optional extra that you choose will be free.
Otherwise, if you choose other methods:
1)EMI over 4 years then, you must pay per month over 4 years with no extra charges whether you are repeated customer or not.
2)EMI over 7 years then, you must pay per month over 7 years with 5% extra charges whether you are repeated customer or not.\n''')
payment_method=input("Please! Choose the payment methods(fullpayment/EMI_over_fouryears/EMI_over_sevenyears:") #Task 2
existing_customer=input("Were you visited our shop already(Yes or No)?") #task 3
if payment_method=="fullpayment" and existing_customer=="Yes":
    cash_back=input("Do you want cash back(Yes or No)?")
    if cash_back=="Yes" and customer_choice=="Hatchback":
            total=tot-(535000*0.01)
            print("Now,Your total payment after 1% cashback :",total)
    elif cash_back=="Yes" and customer_choice=="Saloon":
            total=tot-(495000*0.01)
            print("Now,Your total payment after 1% cashback:",total)
    elif cash_back=="Yes" and customer_choice=="Saloon":
            total=tot-(625000*0.01)
            print("Now,Your total payment after 1% cashback:",total)
    else:
        choose_free_service=input("Choose the feature that will be free to you(Luxury budget/Satellite navigation/Parking sensors/Bluetooth connect/Sound system):")
        if choose_free_service=="Luxury budget" and customer_choice=="Hatchback":
                    total=total-45000
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Satellite navigation" and customer_choice=="Hatchback":
                    total=tot-5500
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Parking sensors" and customer_choice=="Hatchback":
                    total=tot-10000
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Bluetooth connect" and customer_choice=="Hatchback":
                    total=tot-350
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Sound system" and customer_choice=="Hatchback":
                    total=tot-1000
                    print("This is your final amount that you have to pay:",total)
         
        elif choose_free_service=="Luxury budget" and customer_choice=="Saloon":
                    total=tot-45000
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Satellite navigation" and customer_choice=="Saloon":
                    total=tot-5500 
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Parking sensors" and customer_choice=="Saloon":
                    total=tot-10000
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Bluetooth connect" and customer_choice=="Saloon":
                    total=tot-350
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Sound system" and customer_choice=="Saloon":
                    total=tot-1000
                    print("This is your final amount that you have to pay:",total)
                
        elif choose_free_service=="Luxury budget" and customer_choice=="Estate":
                    total=tot-1000
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Satellite navigation" and customer_choice=="Estate":
                    total=tot-5500
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Parking sensors" and customer_choice=="Estate":
                    total=tot-10000
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Bluetooth connect" and customer_choice=="Estate":
                    total=tot-350
                    print("This is your final amount that you have to pay:",total)
        elif choose_free_service=="Sound system" and customer_choice=="Estate":
                    total=tot-1000
                    print("This is your final amount that you have to pay:",total)
elif payment_method=="EMI_over_fouryears":
    if existing_customer=="Yes":
        tot=tot/48  #4years=4*12months
        print("Now,Your total payment is:",tot,"per month")
    else:
        print("\nThere is no offers of cashback or free optional service for EMI methods\n")
        tot=tot/48  #4years=4*12months
        print("Now,Your total payment is:",tot,"per month")
elif payment_method=="EMI_over_sevenyears":
    if existing_customer=="Yes":
        tot=tot+(tot*0.05)
        print("Now,Your total payment is:",tot,"per month")
    else:
        print("There is no offers of cashback or free optional service for EMI methods")
        tot=tot+(tot*0.05)
        print("Now,Your total payment is:",tot,"per month")
else:
    print("\nSorry!Offers are only for fullpayment and repeated customers.Your final amount is",tot)
# Out:
# Please! Enter your name:tntg
#
# Welcome To The Snazzy Auto Shop! tntg
#
# These are available models of car:
# Hatchback:Rs 5.35Lakhs
# Saloon:Rs 4.95Lakhs
# Estate:Rs 6.25Lakhs
#
# These are facilities provided in our car:
# Luxury budget:Rs 45000
# Satellite navigation:Rs 5500
# Parking sensors:1000
# Bluetooth connect:350
# Sound system:Rs 1000
#
# Please! enter your choosen car model(Hatchback/Saloon/Estate):Hatchback
# Please enter your choice of facilities(Luxury budget/Satellite navigation/Parking sensors/Bluetooth connect/Sound system):Sound system
# Are you have old car?(Yes or No):yea
# So, you don't have old car.
# Your total price is: 536000
#
# The total amount that you have to pay is: 536000
#
# For getting excited offers, select your suitable payment methods.
#
#
# If you choose fullpayment methods and you are repeated customers then you have two options:
# 1)1% Cashback of your total payment.
# 2)Any one optional extra that you choose will be free.
# ...
